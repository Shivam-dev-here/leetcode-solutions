# %% [markdown]
# # Solution

# %%
class Solution(object):
    def maximumWealth(self, accounts):
        mmax=0
        for i in accounts:
            max=0
            for j in i:
                max += j
            if(mmax<max):
                mmax=max
        return mmax

# %% [markdown]
# # Test 1

# %%
m=2
n=2
account = [[1,2,3],[2,3,2]]
cmax= 0
for i in range(m):
    rmax=0
    for j in range(n):
        # print(account[i][j])
        rmax += account[i][j]
        print(rmax)
    if(cmax<rmax):
        cmax = rmax

print(cmax)

# %% [markdown]
# # Test 2

# %%
account = [[1,2,3],[2,3,2]]

mmax=0
for i in account:
    max=0
    for j in i:
        print(j, end="")
        max += j
    if(mmax<max):
        mmax=max
    print("")
print(max)
