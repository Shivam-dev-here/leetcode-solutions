# %% [markdown]
# # Solution

# %%
class Solution(object):
    def numberOfSteps(self, num):
        c=0
        while num > 0:
            if(num%2==0):
                num = num / 2
                c+=1
            else:
                num -=1
                c+=1
        return c

# %% [markdown]
# # TEST

# %%
num = 123
c=0
while num > 0:
    if(num%2==0):
        num = num / 2
        c+=1
    else:
        num -=1
        c+=1
    
print(c)
# Out:
# 12
